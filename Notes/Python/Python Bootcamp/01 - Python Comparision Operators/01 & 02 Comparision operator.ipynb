# %% [markdown]
# $$ ``` Comparision Operators ``` $$

# %%
2 == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %% [markdown]
# Logical Operators
#
# AND, OR, NOT

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
5 < 2 or 2 > 3
# Out:
# False

# %%
not 4 == 4
# Out:
# False
