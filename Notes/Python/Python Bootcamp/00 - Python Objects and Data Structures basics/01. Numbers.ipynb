# %% [markdown]
# #### $$ 01 - Numbers $$

# %% [markdown]
# ```python
# What is Data Type?
# It defines a varibale what data it will be holding and operation that can be performed.
#
# They are two types of Data types:
# 1. Premitive - single valued types
#
# Int     -> Whole numbers --> 10
# Float   -> decimal numbers --> 3.5
# complex -> Complex numbers --> 2 + 3j
# bool    -> True / False --> True
# str     -> text values --> "Hello"
#
# 2. Non- Premitive -- multiple valued
#
# List       (Mutable, Ordered)         -> lst=[1,2,"go",5]
# tuple      (unmutable, Ordered)       -> tup=(1,"go",3,"good")
# set        (Unordered, unique values) -> set=(1,2,3)
# Dictinoary (key: value pair)          -> dict={"A":"excellent", "B":"Good", "C": "Average"}
#
# *Mutable - Can change after creation in place (list, set, dict)
# *Immutable - cannot change after creation (int,float, bool, str, tuple)
# ```

# %% [markdown]
# ```python
# Data types:
# 1. Strings(Str) - ordered sequence of characters.
#                   Ex: "hello" "good"
#
# 2. Intgers(Int) - Whole numbers.
#                   Ex:2 400 50
#
# 3. Float(float) - numbers with decimal points.
#                   Ex: 3.5  456.6
#
# 4. Boolens(Bool) - logical value indicating True / False.
#
# 5. Lists(list) - ordered sequence of objects.
#                   Ex: [1,"hello", 4,"good"]
#
# 6. Dictinaries(Dict) - unordered key:value pairs.
#                   Ex: {"A":"Excellent"
#                        "B":"Good"
#                        "C":"Average"
#                        }
#
# 7. Tuples(Tup) - ordered immutable sequence of objects.
#                 Ex: (10,"hello",4,"good")
#
# 8. Sets(set) - unordered collection of unique objects.
#                 Ex: ("A","B")
# ```

# %% [markdown]
# ### ```Operators```

# %%
#Division
7 /4
# Out:
# 1.75

# %%
#addition
5 + 5
# Out:
# 10

# %%
#multiplication
25 * 5
# Out:
# 125

# %%
#Subtraction
25 - 10
# Out:
# 15

# %%
#Modulo or MOD operator
50 % 10
# Out:
# 0

# %%
#General Odd or even check
#0 - even
#1 - odd
20 % 2
# Out:
# 0

# %%
2 ** 3
# Out:
# 8

# %%
#PEMDAS
2 + (10 *3) / 6
# Out:
# 7.0

# %% [markdown]
# ```python
# Knowledge:
# 01. diff b/w float and integer
# A: An intger is a non decimal number, while decimal is a number having point at any large or small number.
#
# 02. if we add 2 + 3.0 = 5.0 not 5?
# A: A integer number which is operated on float it will result in decimal.
#
# 03. Can we calculate int & Str?
# A: We cannot calculate a number(5) and string("AB") where AB is not a value but if the string is of number then we can type cast the string and calculate.
# ```

# %% [markdown]
# ### ```Variable Assignment```
