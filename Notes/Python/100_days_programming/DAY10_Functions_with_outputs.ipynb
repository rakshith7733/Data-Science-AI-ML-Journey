# %% [markdown]
# $$ DAY 10: Functions-with-Ouputs $$

# %% [markdown]
# ```python
# Funtions with outputs
#
# def my_function(parameters,....):
#     result = operations
#     return result
#
#
# my_function(arguments,....)
# ```

# %%
#Function with return statement.
def format_name(f_name,l_name):
    fl_name = f_name +" " + l_name
    return fl_name.title()

#Title() - return a version of the string where the words start with upper case and remaining with lower case.

format_name(f_name = input("enter the first name: "),l_name = input("enter last name: "))
# Out:
# 'Good Vibes'

# %%
#Function with multiple return statements.

def format_name(f_name,l_name):
    if f_name == "" or l_name == "":
        return  #just keeping simple return statements it will bypass the rest of the code in exception block.
    fl_name = f_name +" " + l_name
    return fl_name.title()

format_name(f_name = input("enter the first name: "),l_name = input("enter last name: "))
# Out:
# 'Rakshith Kumar'

# %% [markdown]
# ```python
# Docstring: Docstrings in Python are string literals that appear as the first statement in a module, function, class, or method definition.
# - They serve as the primary mechanism for documenting code, providing a concise explanation of what the object does, its parameters, and its return values
# ```

# %%
#Example usage of Docstring in functions.

def format_name(f_name,l_name):
    """This function is used to take first name, last name based on inputs it will concatenate and fetch the name in title version."""
    if f_name == "" or l_name == "":
        return  #just keeping simple return statements it will bypass the rest of the code in exception block.
    fl_name = f_name +" " + l_name
    return fl_name.title()

format_name(f_name = input("enter the first name: "),l_name = input("enter last name: "))
# Out:
# 'Apple Laptop'

# %%
#DAY10 Project: Python Calculator.
from calcs_art import logo

print(logo)
print("Welcome to Python Calculator!")


#TODO-1: Write out the functions - add, subtract, multiply, divide.
#Operational functions.
def add(number_1, number_2):
    '''Function to add two numbers.'''
    return number_1 + number_2

def sub(number_1, number_2):
    '''Function to subtract two numbers.'''
    return number_1 - number_2

def mul(number_1, number_2):
    '''Function to multiply two numbers.'''
    return number_1 * number_2

def div(number_1, number_2):
    '''Function to divide two numbers.'''
    return number_1 / number_2

#TODO-2: Add these 4 functions into a dictionary as the values. keys = "+","-","*","/".

operation_dict = {"+":add,
                  "-":sub,
                  "*":mul,
                  "/":div
}

def calculator():
    num_1 = float(input("What's the first number?: "))
    should_accumulate = True

    while should_accumulate:
        for symbol in operation_dict:
            print(symbol)

        operation_symbols = input("pick your operation: ")

        num_2 = float(input("What's the next number?: "))


        empty_dict = {}
    #TODO-3: Use the dictonary operations to perform the operations.
        calculation_function = operation_dict[operation_symbols]
        result = calculation_function(num_1,num_2)

        print(f"{num_1} {operation_symbols} {num_2} = {result}")

        #asking user whether will you proceed with last calculation will do new calculation.
        choice = input(f"Type 'y' to continue calculating with {empty_dict}, or 'n' to start a new calculation: ").lower()

        if choice == "y":
            num_1 = result
        else:
            should_accumulate = False
            calculator()

calculator()
# Out:
#            _            _       _
#           | |          | |     | |
#   ___ __ _| | ___ _   _| | __ _| |_ ___  _ __
#  / __/ _` | |/ __| | | | |/ _` | __/ _ \| '__|
# | (_| (_| | | (__| |_| | | (_| | || (_) | |
#  \___\__,_|_|\___|\__,_|_|\__,_|\__\___/|_|
#
# Welcome to Python Calculator!
# +
# -
# *
# /
# 5.0 * 5.0 = 25.0
# +
# -
# *
# /
# 25.0 * 5.0 = 125.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 63
#      60             should_accumulate = False
#      61             calculator()
# ---> 63 calculator()
#
# Cell In[2], line 61, in calculator()
#      59 else:
#      60     should_accumulate = False
# ---> 61     calculator()
#
# Cell In[2], line 35, in calculator()
#      34 def calculator():
# ---> 35     num_1 = float(input("What's the first number?: "))
#      36     should_accumulate = True
#      38     while should_accumulate:
#
# ...
