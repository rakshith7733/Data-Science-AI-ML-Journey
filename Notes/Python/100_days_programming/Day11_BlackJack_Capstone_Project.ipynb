# %% [markdown]
# Program Requirements:
# Blackjack 21
#
# - This is played using cards and when you get cards you should not cross 21 which is bust/lose game.
#
# - Until and unless you are less than 21 (combined cards) and less than opponent count you win.
#
# * Number cards are number as they are
# * cards like (K,Q,J) = 10
# * Ace cards(A) = 1 or 11 based on the situation.
#
#
# rules:
# if you go over 21 either dealer or you will be lose.
# if you and dealer having same score under 21 it will be draw.
# if dealer score 21 and you score is below 21 you lose.
# if less than 16 they need to take another card.

# %% [markdown]
# sample(value,no ofitems) - This will pick random no values from a list.

# %%
#Day 11 Project: BlackJack Capstone[normal].
from blackjack_art import logo
import random

#print(logo)

#user_choice = input("Do you want to play a game of Blackjack? Type 'y' or 'n': ").lower()

cards = [11,2,3,4,5,6,7,8,9,10,10,10,10]

#logic for user inputs taking sample two items in a list.
user_two_decks = random.sample(cards,2)
combined_score = sum(user_two_decks)
#print(user_two_decks)
print(f"Your cards: {user_two_decks}, Current score: {combined_score}.")

#logic for computer to take inputs
computer_decks = random.sample(cards,2)
combined_c_Score = sum(computer_decks)
#print(computer_decks)
print(f"Computer's first Card: {computer_decks[0]}")

# your_cards: [9,10]
# computer's first card: 8
# Type 'y' to get another card, type 'n' to pass:
# Out:
# Your cards: [8, 10], Current score: 18.
# [9, 10]
# Computer's first Card: 9
